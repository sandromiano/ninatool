# %%
from ninatool.internal.elements import L, J
from ninatool.internal.structures import loop
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_33436\2471787049.py in <module>
#       1 from ninatool.internal.elements import L, J
# ----> 2 from ninatool.internal.structures import loop
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
#
# ~\miniconda3\envs\nina\lib\site-packages\ninatool\internal\structures.py in <module>
#      12 default_phase_array = NUM_PERIODS * 2 * pi * np.linspace(-.5, .5, NUM_POINTS)
#      13
# ---> 14 class branch(Nlind):
#      15     '''
#      16     Series combination of linear inductances and Josephson junctions.
#
# ~\miniconda3\envs\nina\lib\site-packages\ninatool\internal\structures.py in branch()
#      19     '''
#      20     def __init__(self,
# ---> 21                  elements = [L(1)],
#      22                  is_free = True,
#      23                  name = '',
#
# ~\miniconda3\envs\nina\lib\site-packages\ninatool\internal\elements.py in __init__(self, L, order, name)
#     226             Name of L instance.
#     227         '''
# --> 228         super().__init__(order = order)
#     229
#     230         self._Nlind__kind = 'L'
#
# ~\miniconda3\envs\nina\lib\site-packages\ninatool\internal\elements.py in __init__(self, order, name)
#      22
#      23         self.__order = order
# ---> 24         self.__invert_repr = invert_representation_partial(self.order)
#      25         self.__series_combination = series_combination_partial(self.order)
#      26
#
# ~\miniconda3\envs\nina\lib\site-packages\ninatool\internal\support_functions.py in invert_representation_partial(order)
#      96     fs = []
#      97
# ---> 98     with open(filepath, 'r') as file:
#      99         fs = [file.readline().strip('\n') for i in range(order)]
#     100
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\sandro-office\\miniconda3\\envs\\nina\\lib\\site-packages\\ninatool\\internal/mapping_functions/invert_representation_O30.txt'

# %%
#maximum order of expansion, order = 1 means linear order
order = 4

#left branch elements
J0 = J(1, order = order, name = 'J0')
L0 = L(.1, order = order, name = 'L0')
#right branch elements
J1 = J(.5, order = order, name = 'J1')
L1 = L(.1, order = order, name = 'L1')

dcsquid = loop(left_branch = [J0, L0], right_branch = [J1, L1], name = 'dcsquid')

# %%
#sets the phase of the free JJ
dcsquid.free_phi = np.linspace(-1,1,101) * 2 * np.pi

# %%
#plots second order expansion coefficient (u2) VS flux
plt.plot(dcsquid.flux, dcsquid.adm[0])
plt.xlabel('dcsquid.flux')
plt.ylabel('dcsquid.u2')
# Out:
# Text(0, 0.5, 'dcsquid.u2')

# %%
#plots third order expansion coefficient (u3) VS flux
plt.plot(dcsquid.flux, dcsquid.adm[1])
plt.xlabel('dcsquid.flux')
plt.ylabel('dcsquid.u3')
# Out:
# Text(0, 0.5, 'dcsquid.u3')

# %%
#plots second order expansion coefficient (u2) VS flux, with changes in J1 critical current

#this syntax updates the critical current of J1 and automatically updates the dcsquid.
#can be applied to linear inductance as well.
J1.ic = 0.4
plt.plot(dcsquid.flux, dcsquid.adm[0], label = 'J1.ic=' + str(J1.ic))
J1.ic = 0.6
plt.plot(dcsquid.flux, dcsquid.adm[0], label = 'J1.ic=' + str(J1.ic))
plt.legend()
plt.xlabel('dcsquid.flux')
plt.ylabel('dcsquid.u2')
# Out:
# Text(0, 0.5, 'dcsquid.u2')
